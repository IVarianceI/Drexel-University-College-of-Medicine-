# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import os

# %%
cwd =os.getcwd()
os.chdir("/Users/luqingqi/Desktop/Project/18")

# %%
df = pd.read_excel ('TRNEW.xlsx')

# %%
df.head()
# Out:
#    data.RXEXP18  data.DSKIDN53  data.RXSLF18  data.DSEYPR53
# 0             0              2             0              2
# 1           634              2           373              2
# 2           316              2            11              2
# 3           503              2           407              2
# 4          4106              2          2507              1

# %%
df.describe()
# Out:
#         data.RXEXP18  data.DSKIDN53  data.RXSLF18  data.DSEYPR53
# count    1918.000000    1918.000000   1918.000000    1918.000000
# mean     6051.596976       1.883733    569.580813       1.813347
# std      9501.098743       0.320628   1484.134337       0.389734
# min         0.000000       1.000000      0.000000       1.000000
# 25%       593.000000       2.000000     46.000000       2.000000
# 50%      2703.000000       2.000000    200.000000       2.000000
# 75%      7703.000000       2.000000    591.000000       2.000000
# max    105002.000000       2.000000  36375.000000       2.000000

# %%
df.agg(['skew', 'kurtosis']).transpose()
# Out:
#                     skew    kurtosis
# data.RXEXP18    4.103655   26.498460
# data.DSKIDN53  -2.396130    3.745343
# data.RXSLF18   12.240625  227.442172
# data.DSEYPR53  -1.609684    0.591697

# %%
sns.catplot(x="data.RXSLF18", y="data.RXEXP18", data=df)

# %%
sns.catplot(x="data.DSKIDN53", y="data.RXEXP18", data=df)

# %%
sns.catplot(x="data.DSKIDN53", y="data.RXSLF18", data=df)

# %%
sns.catplot(x="data.DSEYPR53", y="data.RXEXP18", data=df)

# %%
sns.catplot(x="data.DSEYPR53", y="data.RXSLF18", data=df)

# %%
sns.catplot(x="data.DSKIDN53", y="data.RXEXP18",
            markers=["^", "o"], linestyles=["-", "--"],
            kind="point", data=df)

# %%
g = sns.catplot(x="data.RXEXP18", y="data.DSEYPR53", row="data.DSKIDN53",
                kind="box", orient="h", height=1.5, aspect=4,
                data=df)
g.set(xscale="log")

# %%
sns.catplot(x="data.DSEYPR53", y="data.RXSLF18", hue="data.DSKIDN53",
            markers=["^", "o"], linestyles=["-", "--"],
            kind="point", data=df)

# %%
g = sns.catplot(x="data.RXSLF18", y="", row="data.DSKIDN53",
                kind="box", orient="h", height=1.5, aspect=4,
                data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-559c49690952> in <module>
# ----> 1 g = sns.catplot(x="data.RXSLF18", y="", row="data.DSKIDN53",
#       2                 kind="box", orient="h", height=1.5, aspect=4,
#       3                 data=df)
#       4 plot.g
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
# ...
